# %%
from nltk.tokenize import word_tokenize
import nltk
from konlpy.tag import Twitter
from selenium import webdriver
import time

# %%
URL = input("네이버 뉴스 기사 댓글창의 URL을 복사해서 입력해주세요")

#https://sports.news.naver.com/news.nhn?oid=477&aid=0000232510&m_view=1&sort=LIKE - 손흥민, 긍정이 많음
# Out:
# 네이버 뉴스 기사 댓글창의 URL을 복사해서 입력해주세요https://sports.news.naver.com/news.nhn?oid=477&aid=0000232510&m_view=1&sort=LIKE

# %%
train_number = input("원하는 학습 데이터의 개수를 입력해 주세요")
# Out:
# 원하는 학습 데이터의 개수를 입력해 주세요30

# %%
print(URL,train_number)
# Out:
# https://sports.news.naver.com/news.nhn?oid=477&aid=0000232510&m_view=1&sort=LIKE 30

# %%
#웹 드라이버
driver = webdriver.Chrome('./chromedriver.exe') 
driver.implicitly_wait(30)
driver.get(URL)

#더보기 계속 클릭하기
more_count = 0
while True:
    try:
        더보기 = driver.find_element_by_css_selector('a.u_cbox_btn_more')
        더보기.click()
        time.sleep(1)
        more_count = more_count + 1
        if more_count > 10 :
            break
    except:
        break

# %%
#댓글추출
contents = driver.find_elements_by_css_selector('span.u_cbox_contents')
text_list = []

for content in contents:
    #print(content.text) #추후 삭제
    text_list.append(content.text)

# %%
total_length = len(text_list)
print("추출한 댓글의 갯수는 " + str(total_length) + "개 입니다.")
# Out:
# 추출한 댓글의 갯수는 239개 입니다.

# %%
#학습 데이터 추출
train_count = 0
train_number = int(train_number)
train_list=[]


while train_count < train_number :
    print(str(train_count) + "번째 train data 입니다. 남은 학습 수 : " +str(train_number-train_count))
    print(text_list[train_count])
    text = text_list[train_count]
    #(텍스트, 긍부정여부) 튜플에 넣을 text 데이터
    
    print("학습 데이터의 긍부정 여부를 입력해 주세요 ")
    NB = input("긍정 : 1 , 부정 : 2, 중립 :3 : ") # Naive Bayes classification
    NB = int(NB) #형변환
    
    if(NB is 1) :
        print("긍정입니다")
        NB = "pos"
        
    elif (NB is 2) :
        print("부정입니다.")
        NB = "neg"
        
    else :
        print("pass")
        train_count = train_count + 1
        continue
    
    train_list.append((text,NB))
    train_count = train_count + 1
    print("")
    
    
print(train_list)
# Out:
# 0번째 train data 입니다. 남은 학습 수 : 30
# 손흥민 지렸다
# 학습 데이터의 긍부정 여부를 입력해 주세요
# 긍정 : 1 , 부정 : 2, 중립 :3 : 1
# 긍정입니다
#
# 1번째 train data 입니다. 남은 학습 수 : 29
# 레이나 야신모드에 놀라고 손흥민 극장골에 놀랐다
# 학습 데이터의 긍부정 여부를 입력해 주세요
# 긍정 : 1 , 부정 : 2, 중립 :3 : 1
# 긍정입니다
#
# 2번째 train data 입니다. 남은 학습 수 : 28
# 손까들이 암만욕해도 결국 에이스는 손흥민이다
# 학습 데이터의 긍부정 여부를 입력해 주세요
# 긍정 : 1 , 부정 : 2, 중립 :3 : 1
# 긍정입니다
#
# 3번째 train data 입니다. 남은 학습 수 : 27
# 손흥민 마지막 극장골 멋있었다
# 학습 데이터의 긍부정 여부를 입력해 주세요
# 긍정 : 1 , 부정 : 2, 중립 :3 : 1
# 긍정입니다
#
# 4번째 train data 입니다. 남은 학습 수 : 26
# 첫 5경기 연속골에 오늘 멀티골 충분히 잘했다
# 학습 데이터의 긍부정 여부를 입력해 주세요
# 긍정 : 1 , 부정 : 2, 중립 :3 : 1
# 긍정입니다
#
# 5번째 train data 입니다. 남은 학습 수 : 25
# 오늘진짜 토트넘 이길경기력은 아니었는데 손흥민도 폼다안올라왔고 근데이걸 전.후반 추가시간에 넣고 이기네 이게 에이스지
# 학습 데이터의 긍부정 여부를 입력해 주세요
# 긍정 : 1 , 부정 : 2, 중립 :3 : 1
# 긍정입니다
#
# 6번째 train data 입니다. 남은 학습 수 : 24
# 이러니까 무리뉴가 중간에 손흥민을 못빼지!!! 극장골 소름!!!!
# 학습 데이터의 긍부정 여부를 입력해 주세요
# 긍정 : 1 , 부정 : 2, 중립 :3 : 1
# 긍정입니다
#
# 7번째 train data 입니다. 남은 학습 수 : 23
# 경기 끝까지 본 자가 승자
# 학습 데이터의 긍부정 여부를 입력해 주세요
# 긍정 : 1 , 부정 : 2, 중립 :3 : 3
# pass
# 8번째 train data 입니다. 남은 학습 수 : 22
# 베르통언:이걸 샤워해 말어
# 학습 데이터의 긍부정 여부를 입력해 주세요
# 긍정 : 1 , 부정 : 2, 중립 :3 : 2
# 부정입니다.
#
# 9번째 train data 입니다. 남은 학습 수 : 21
# 레이나에서 손흥민으로 MOM이 바뀌는 버저비터
# 학습 데이터의 긍부정 여부를 입력해 주세요
# 긍정 : 1 , 부정 : 2, 중립 :3 : 3
# pass
# 10번째 train data 입니다. 남은 학습 수 : 20
# 투병중인데 아픈거 순간 잊었다
# 학습 데이터의 긍부정 여부를 입력해 주세요
# 긍정 : 1 , 부정 : 2, 중립 :3 : 1
# 긍정입니다
#
# 11번째 train data 입니다. 남은 학습 수 : 19
# 승리 후 하회탈 세러머니 지렸다!!
# 학습 데이터의 긍부정 여부를 입력해 주세요
# 긍정 : 1 , 부정 : 2, 중립 :3 : 1
# 긍정입니다
#
# 12번째 train data 입니다. 남은 학습 수 : 18
# 오늘 경기본 사람은 이번주 대박납니다.
# 학습 데이터의 긍부정 여부를 입력해 주세요
# 긍정 : 1 , 부정 : 2, 중립 :3 : 3
# pass
# 13번째 train data 입니다. 남은 학습 수 : 17
# 대박ㅋㅋ 무리뉴가 손을 못 빼는 이유... 사랑하는 이유네
# 학습 데이터의 긍부정 여부를 입력해 주세요
# 긍정 : 1 , 부정 : 2, 중립 :3 : 1
# 긍정입니다
#
# 14번째 train data 입니다. 남은 학습 수 : 16
# 마지막 얀 교체되서 들어가는 거 좀 짠하더라
# 학습 데이터의 긍부정 여부를 입력해 주세요
# 긍정 : 1 , 부정 : 2, 중립 :3 : 2
# 부정입니다.
#
# 15번째 train data 입니다. 남은 학습 수 : 15
# 마지막도 손흥민이니까 넣은거임. 모우라였으면 느려서 못넣었음
# 학습 데이터의 긍부정 여부를 입력해 주세요
# 긍정 : 1 , 부정 : 2, 중립 :3 : 3
# pass
# 16번째 train data 입니다. 남은 학습 수 : 14
# 손까들 죄다 조선족에 중국 유학생들임. 신경꺼됨
# 학습 데이터의 긍부정 여부를 입력해 주세요
# 긍정 : 1 , 부정 : 2, 중립 :3 : 2
# 부정입니다.
#
# 17번째 train data 입니다. 남은 학습 수 : 13
# 레이나개잘했는데 극장나오네 ㅋㅋ
# 학습 데이터의 긍부정 여부를 입력해 주세요
# 긍정 : 1 , 부정 : 2, 중립 :3 : 3
# pass
# 18번째 train data 입니다. 남은 학습 수 : 12
# 손흥민은 월클이다
# 학습 데이터의 긍부정 여부를 입력해 주세요
# 긍정 : 1 , 부정 : 2, 중립 :3 : 1
# 긍정입니다
#
# 19번째 train data 입니다. 남은 학습 수 : 11
# 레이나 잘하고 있다가 마지막 개사이다 ㅋㅋㅋㅋㅋㅋ
# 학습 데이터의 긍부정 여부를 입력해 주세요
# 긍정 : 1 , 부정 : 2, 중립 :3 : 3
# pass
# 20번째 train data 입니다. 남은 학습 수 : 10
# 베르바인은 2년 안에 팀의 주축 선수가 될 수 있다... 좋은 선수를 데려 왔군...
# 학습 데이터의 긍부정 여부를 입력해 주세요
# 긍정 : 1 , 부정 : 2, 중립 :3 : 1
# 긍정입니다
#
# 21번째 train data 입니다. 남은 학습 수 : 9
# 마지막골은 진짜 해결사만 넣을수 있는 골이다
# 학습 데이터의 긍부정 여부를 입력해 주세요
# 긍정 : 1 , 부정 : 2, 중립 :3 : 1
# 긍정입니다
#
# 22번째 train data 입니다. 남은 학습 수 : 8
# 말이되냐?대한민국 선수가 EPL을 호령하고 있다.
# 학습 데이터의 긍부정 여부를 입력해 주세요
# 긍정 : 1 , 부정 : 2, 중립 :3 : 1
# 긍정입니다
#
# 23번째 train data 입니다. 남은 학습 수 : 7
# 컨디션이 좋아보이진 않았는데 왜 에이스인지 슈퍼스타인지 증명해 내더라... 박지성형 울버햄프턴하고 했을때 생각나는 버저비터더라
# 학습 데이터의 긍부정 여부를 입력해 주세요
# 긍정 : 1 , 부정 : 2, 중립 :3 : 1
# 긍정입니다
#
# 24번째 train data 입니다. 남은 학습 수 : 6
# 코너킥. 페널티킥. 후리킥. 필드골. 다 손이 하네. 지금은 토트넘에서 손밖에없다. 오늘 실수도 했지만. 그나마 공잡으면 기대를 조금 하게 만드는게 공격수다.
# 학습 데이터의 긍부정 여부를 입력해 주세요
# 긍정 : 1 , 부정 : 2, 중립 :3 : 1
# 긍정입니다
#
# 25번째 train data 입니다. 남은 학습 수 : 5
# 마지막에 역시 손흥민이다란 말이 나왓다 결정적 기회 날린 알리보다는 찬스에서 믿음이 더간다. 알리보다 낫다는게 아니라 찬스에서는 가장 위협적이란 말
# 학습 데이터의 긍부정 여부를 입력해 주세요
# 긍정 : 1 , 부정 : 2, 중립 :3 : 1
# 긍정입니다
#
# 26번째 train data 입니다. 남은 학습 수 : 4
# 미친 경기 손흥민!!!
# 학습 데이터의 긍부정 여부를 입력해 주세요
# 긍정 : 1 , 부정 : 2, 중립 :3 : 1
# 긍정입니다
#
# 27번째 train data 입니다. 남은 학습 수 : 3
# 소리질러서 가족들 다 깨운분?
# 학습 데이터의 긍부정 여부를 입력해 주세요
# 긍정 : 1 , 부정 : 2, 중립 :3 : 3
# pass
# 28번째 train data 입니다. 남은 학습 수 : 2
# 끝까지 본사람이 승자 ㅋㅋㅋㅋㅋㅋㅋㅋ
# 학습 데이터의 긍부정 여부를 입력해 주세요
# 긍정 : 1 , 부정 : 2, 중립 :3 : 1
# 긍정입니다
#
# 29번째 train data 입니다. 남은 학습 수 : 1
# 초반 볼터치보고 컨디션 별로인가 싶었지만 골로 보여주네
# 학습 데이터의 긍부정 여부를 입력해 주세요
# 긍정 : 1 , 부정 : 2, 중립 :3 : 1
# 긍정입니다
#
# [('손흥민 지렸다', 'pos'), ('레이나 야신모드에 놀라고 손흥민 극장골에 놀랐다', 'pos'), ('손까들이 암만욕해도 결국 에이스는 손흥민이다', 'pos'), ('손흥민 마지막 극장골 멋있었다', 'pos'), ('첫 5경기 연속골에 오늘 멀티골 충분히 잘했다', 'pos'), ('오늘진짜 토트넘 이길경기력은 아니었는데 손흥민도 폼다안올라왔고 근데이걸 전.후반 추가시간에 넣고 이기네 이게 에이스지', 'pos'), ('이러니까 무리뉴가 중간에 손흥민을 못빼지!!! 극장골 소름!!!!', 'pos'), ('베르통언:이걸 샤워해 말어', 'neg'), ('투병중인데 아픈거 순간 잊었다', 'pos'), ('승리 후 하회탈 세러머니 지렸다!!', 'pos'), ('대박ㅋㅋ 무리뉴가 손을 못 빼는 이유... 사랑하는 이유네', 'pos'), ('마지막 얀 교체되서 들어가는 거 좀 짠하더라', 'neg'), ('손까들 죄다 조선족에 중국 유학생들임. 신경꺼됨', 'neg'), ('손흥민은 월클이다', 'pos'), ('베르바인은 2년 안에 팀의 주축 선수가 될 수 있다... 좋은 선수를 데려 왔군...', 'pos'), ('마지막골은 진짜 해결사만 넣을수 있는 골이다', 'pos'), ('말이되냐?대한민국 선수가 EPL을 호령하고 있다.', 'pos'), ('컨디션이 좋아보이진 않았는데 왜 에이스인지 슈퍼스타인지 증명해 내더라... 박지성형 울버햄프턴하고 했을때 생각나는 버저비터더라', 'pos'), ('코너킥. 페널티킥. 후리킥. 필드골. 다 손이 하네. 지금은 토트넘에서 손밖에없다. 오늘 실수도 했지만. 그나마 공잡으면 기대를 조금 하게 만드는게 공격수다.', 'pos'), ('마지막에 역시 손흥민이다란 말이 나왓다 결정적 기회 날린 알리보다는 찬스에서 믿음이 더간다. 알리보다 낫다는게 아니라 찬스에서는 가장 위협적이란 말', 'pos'), ('미친 경기 손흥민!!!', 'pos'), ('끝까지 본사람이 승자 ㅋㅋㅋㅋㅋㅋㅋㅋ', 'pos'), ('초반 볼터치보고 컨디션 별로인가 싶었지만 골로 보여주네', 'pos')]

# %%
# 분석 모델 작성

pos_tagger = Twitter()

def tokenize(doc):
    return ['/'.join(t) for t in pos_tagger.pos(doc, norm=True, stem=True)]
    #형태소 분석된 결과에 태그를 붙여주는 과정.

train_docs = [(tokenize(row[0]), row[1]) for row in train_list]
train_docs
# 학습 데이터를 형태소 분석

tokens = [t for d in train_docs for t in d[0]]
tokens
# 형태소 분석한 학습데이터들을 기반으로 단어뭉치 생성

def term_exists(doc):
    return {word: (word in set(doc)) for word in tokens}
#해당 문장에 단어뭉치 속 단어가 존재하는지 판단하는 함수.

train_xy = [(term_exists(d), c) for d,c in train_docs]
train_xy
# 학습 문장 속 단어와 단어 뭉치 속 단어를 비교.


classifier = nltk.NaiveBayesClassifier.train(train_xy)
classifier.show_most_informative_features()
#비교한 값을 학습 데이터로 하여 분석기 완성
# Out:
# Most Informative Features
#                 들이다/Verb = True              neg : pos    =      5.2 : 1.0
#                   걸/Noun = True              neg : pos    =      5.2 : 1.0
#                  되다/Verb = True              neg : pos    =      5.2 : 1.0
#             이/Determiner = True              neg : pos    =      5.2 : 1.0
#                  끄다/Verb = True              neg : pos    =      5.2 : 1.0
#                  되다/Verb = False             pos : neg    =      2.3 : 1.0
#                   손/Noun = True              neg : pos    =      2.2 : 1.0
#                 마지막/Noun = True              neg : pos    =      2.2 : 1.0
#                  하다/Verb = True              neg : pos    =      1.8 : 1.0
#            ./Punctuation = True              neg : pos    =      1.8 : 1.0

# %%
# 위에서 만든 모델에 전체 text data를 넣어 분석
text_count = 0
pos_count = 0
neg_count = 0
for i in text_list :
    for_test_sentence = "'" + i + "'" 

    for_test_docs = tokenize(for_test_sentence)

    for_test_sent_features = term_exists(for_test_docs)
    
    print("'" + i + "' 의 긍부정 판정 결과는 " + classifier.classify(for_test_sent_features) + "입니다.")
      
    if classifier.classify(for_test_sent_features) == 'neg' :
        neg_count = neg_count + 1
    else :
        pos_count = pos_count + 1
        
    text_count = text_count + 1
    
    #if text_count == 100 :
    #    break
# Out:
# '손흥민 지렸다' 의 긍부정 판정 결과는 pos입니다.
# '레이나 야신모드에 놀라고 손흥민 극장골에 놀랐다' 의 긍부정 판정 결과는 pos입니다.
# '손까들이 암만욕해도 결국 에이스는 손흥민이다' 의 긍부정 판정 결과는 pos입니다.
# '손흥민 마지막 극장골 멋있었다' 의 긍부정 판정 결과는 pos입니다.
# '첫 5경기 연속골에 오늘 멀티골 충분히 잘했다' 의 긍부정 판정 결과는 pos입니다.
# '오늘진짜 토트넘 이길경기력은 아니었는데 손흥민도 폼다안올라왔고 근데이걸 전.후반 추가시간에 넣고 이기네 이게 에이스지' 의 긍부정 판정 결과는 pos입니다.
# '이러니까 무리뉴가 중간에 손흥민을 못빼지!!! 극장골 소름!!!!' 의 긍부정 판정 결과는 pos입니다.
# '경기 끝까지 본 자가 승자' 의 긍부정 판정 결과는 pos입니다.
# '베르통언:이걸 샤워해 말어' 의 긍부정 판정 결과는 pos입니다.
# '레이나에서 손흥민으로 MOM이 바뀌는 버저비터' 의 긍부정 판정 결과는 pos입니다.
# '투병중인데 아픈거 순간 잊었다' 의 긍부정 판정 결과는 pos입니다.
# '승리 후 하회탈 세러머니 지렸다!!' 의 긍부정 판정 결과는 pos입니다.
# '오늘 경기본 사람은 이번주 대박납니다.' 의 긍부정 판정 결과는 pos입니다.
# '대박ㅋㅋ 무리뉴가 손을 못 빼는 이유... 사랑하는 이유네' 의 긍부정 판정 결과는 pos입니다.
# '마지막 얀 교체되서 들어가는 거 좀 짠하더라' 의 긍부정 판정 결과는 neg입니다.
# '마지막도 손흥민이니까 넣은거임. 모우라였으면 느려서 못넣었음' 의 긍부정 판정 결과는 pos입니다.
# '손까들 죄다 조선족에 중국 유학생들임. 신경꺼됨' 의 긍부정 판정 결과는 neg입니다.
# '레이나개잘했는데 극장나오네 ㅋㅋ' 의 긍부정 판정 결과는 pos입니다.
# '손흥민은 월클이다' 의 긍부정 판정 결과는 pos입니다.
# '레이나 잘하고 있다가 마지막 개사이다 ㅋㅋㅋㅋㅋㅋ' 의 긍부정 판정 결과는 pos입니다.
# '베르바인은 2년 안에 팀의 주축 선수가 될 수 있다... 좋은 선수를 데려 왔군...' 의 긍부정 판정 결과는 pos입니다.
# '마지막골은 진짜 해결사만 넣을수 있는 골이다' 의 긍부정 판정 결과는 pos입니다.
# '말이되냐?대한민국 선수가 EPL을 호령하고 있다.' 의 긍부정 판정 결과는 pos입니다.
# '컨디션이 좋아보이진 않았는데 왜 에이스인지 슈퍼스타인지 증명해 내더라... 박지성형 울버햄프턴하고 했을때 생각나는 버저비터더라' 의 긍부정 판정 결과는 pos입니다.
# '코너킥. 페널티킥. 후리킥. 필드골. 다 손이 하네. 지금은 토트넘에서 손밖에없다. 오늘 실수도 했지만. 그나마 공잡으면 기대를 조금 하게 만드는게 공격수다.' 의 긍부정 판정 결과는 pos입니다.
# '마지막에 역시 손흥민이다란 말이 나왓다 결정적 기회 날린 알리보다는 찬스에서 믿음이 더간다. 알리보다 낫다는게 아니라 찬스에서는 가장 위협적이란 말' 의 긍부정 판정 결과는 pos입니다.
# '미친 경기 손흥민!!!' 의 긍부정 판정 결과는 pos입니다.
# '소리질러서 가족들 다 깨운분?' 의 긍부정 판정 결과는 pos입니다.
# '끝까지 본사람이 승자 ㅋㅋㅋㅋㅋㅋㅋㅋ' 의 긍부정 판정 결과는 pos입니다.
# '초반 볼터치보고 컨디션 별로인가 싶었지만 골로 보여주네' 의 긍부정 판정 결과는 pos입니다.
# '마지막 버저비터는 넣느냐 못넣느냐에 따라 승점 2점이 왔다갔다 하는 엄청 부담스러운 상황인데 마무리 잘했네 그전 상황들은 아쉬운게 많았어도 결국 공격수는 골로 답하는거지' 의 긍부정 판정 결과는 pos입니다.
# '패널 너무 불안해..ㅜ' 의 긍부정 판정 결과는 pos입니다.
# '폼은 진짜 안좋던데 그래도 이걸 끝내네 ㅎㅎ 오늘 경기 본 사람이 승자다' 의 긍부정 판정 결과는 pos입니다.
# '와 진짜ㅋㅋㅋㅋㅋ 끝났네하고 보는데 진짜 끝내네 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ' 의 긍부정 판정 결과는 pos입니다.
# '무리뉴가 손흥민을 교체시키지 않는 이유' 의 긍부정 판정 결과는 pos입니다.
# '손흥민 지렸다 ㅋㅋㅋㅋㅋㅋ' 의 긍부정 판정 결과는 pos입니다.
# '토트넘의 에이스!!!' 의 긍부정 판정 결과는 pos입니다.
# '근데 솔직히 아스톤빌라 그릴리쉬 칭찬해줘야 한다 진짜 ㅈㄴ 잘하더라' 의 긍부정 판정 결과는 pos입니다.
# '오리에 진짜 개못한다..' 의 긍부정 판정 결과는 pos입니다.
# '물마시고있다가 마지막에 사레걸림' 의 긍부정 판정 결과는 pos입니다.
# '마지막 침착하게 잘했다 역시 에이스는 에이스다.' 의 긍부정 판정 결과는 pos입니다.
# '막판스퍼드 ㄷ ㄷ' 의 긍부정 판정 결과는 pos입니다.
# '네이버 손까들은 중국 조선족과 중국 유학생 입니다.. 그걸 한국인으로 믿지 마세요. 저는 그걸 예전 부터 알고 있었습니다.. 중국인들이 한국 인터넷을 장악하고 있습니다. 이점 잊지 마세요.' 의 긍부정 판정 결과는 pos입니다.
# '꾸역꾸역골 오지네 ㅋㅋ 포체는 흥미니를 빼도 무리뉴는 알리를 빼고 붙박이 점점 경기력 ㅈㅁ해도 골은 넣는게 케인 닮아가냐 근데 터치 포스트 플레이는 많이 아쉽다 ㅋㅋ' 의 긍부정 판정 결과는 pos입니다.
# '진짜 짜증났는데 와 선수는 역시 골 넣으니 다 용서 되네. 화이팅 쏜.' 의 긍부정 판정 결과는 pos입니다.
# '요번에 졌으면 무링뉴행님 머리도 박박밀었것다 산속으로 들어갈뻔했는데 흥민이형이 살렸다 잉' 의 긍부정 판정 결과는 pos입니다.
# '요즘 손흥민 캐릭터가 더 강해지는듯 매시처럼 어슬렁 체력 비축했다가 한방에 쾅. 골냄새 맡는게 월클급되고 있음' 의 긍부정 판정 결과는 pos입니다.
# '기분 뭣같은 헬요일앞두고잠시나마 기분좋았고기분좋은 마음으로 자게 해줘서 고맙다이게 바로 돈값이구나' 의 긍부정 판정 결과는 pos입니다.
# '누가 손흥민 한국갔다오면 멀티골 꼭 박는댔는데 ㅋㅋㅋ딱맟춰버리네' 의 긍부정 판정 결과는 pos입니다.
# '오늘 경기 관전포인트3...1. 손흥민 경기초반 쓰러졌을때 백지장처럼 질려버린 무리뉴 얼굴표정 2. 손흥민 쓰러지고나서 계속 불편해보이는 오른팔 3.경기력은 여전히 한참 좋을때 60-70%밖에 안되어보이는데 꾸역꾸역 득점 행진' 의 긍부정 판정 결과는 pos입니다.
# '대한민국 축구의 자랑~손흥민~흥해라~' 의 긍부정 판정 결과는 pos입니다.
# '94분 다되서 저렇게 뛸수 있다니 대단함' 의 긍부정 판정 결과는 pos입니다.
# '난놈은 난놈이여.... 멀해도 되는놈이네....' 의 긍부정 판정 결과는 pos입니다.
# '거실에서 로셀손가 누군가 헛방 차는거 보고 에이 끝났네 들어가야겠다라고 일어난 순간 갑자기 손흥민이 공잡고 골넣어서 경기를 끝내버리는.. 이건 생방으로 봤었어야 했다 레알 극장골' 의 긍부정 판정 결과는 pos입니다.
# '손흥민이 어떻게든 해결해주네..내가 무리뉴였으면 이뻐서 깨물어죽였다 ㅋㅋ' 의 긍부정 판정 결과는 pos입니다.
# '토트넘은 공격수들이 전부 자리 다툼에 서로 경쟁만 해서 이기적이다. 컷백은 전혀 없고 전부 탐욕 전부 지가 차 넣을려고만 하니 답이 없더라. 베르바인도 잘 보이려고 이 팀에 오자마자 탐욕질.' 의 긍부정 판정 결과는 pos입니다.
# '무리뉴가 손흥민 폼 다 죽어도 절대 안 빼는 이유를 알겠네' 의 긍부정 판정 결과는 pos입니다.
# '손뽕 손까 다떠나서 이맛에 축구보는거 아니겠냐....' 의 긍부정 판정 결과는 pos입니다.
# '베르바인은 2년 안에 팀의 주축 선수가 될 수 있다... 좋은 선수를 데려 왔군... 레이나의 선방이 돋보였던 경기였다고 생각함...' 의 긍부정 판정 결과는 pos입니다.
# '해리 케인 - 25경기 17골 2어시스트 (공격포인트 19개)(경기당 공격 포인트 0.76), 손흥민 - 32경기 16골 9어시스트 (공격 포인트 25개).(경기당 공격 포인트 0.78) 솔직히 손흥민이 케인하고 비교해서 꿀릴 수준은 아니지 않나?' 의 긍부정 판정 결과는 pos입니다.
# '오늘 경기 토트넘은 수비 패스 골굘정력에서 뒤진 경기흐름 이었다. 느린 몸놀림 패스실수 호흡이 맞지않는 경기였고 손흥민도 솔직히 불안했었던 경기였다 그러나 마지막 극장골이 손흥민을 인지하게 하였고 승리를 하여 그나마 다행이었다. 알리 모우라 오늘은 골에리어에서 손흥민에게 패스를 하지 않고 욕심만낸 경기를 했다고 본다. 손흥민이 토트넘을 살린것이다.' 의 긍부정 판정 결과는 pos입니다.
# '마지막에 알리 였음 못넣었다 스피드도 실력' 의 긍부정 판정 결과는 pos입니다.
# '손흥민은 신이내린 선물입니다. EPL팀의 에이스가 한국인이라는 사실이 놀랍지 않습니까?' 의 긍부정 판정 결과는 pos입니다.
# '축구해본사람 공감할듯. 마지막 수비실책전에 침투패스 짧지만 강하게 날라옴. 손흥민 패스속도 판단하고 그냥 돌아뜀. (수비 실책 나올수도 있고 안나올수도 있는 상황) 혹시모를 상황을 기대하며 순간적으로 상대골문쪽으로 돌아뛰겟다는 집중력이 1:1상황 가능하게 한거 같다. 94분에 집중력 정말 대단하다.' 의 긍부정 판정 결과는 pos입니다.
# '넣긴 넣었어도 손흥민 PK 연습 좀 해야겠더라 방향이 너무 보여 케인이 다른건 몰라도 PK는 전세계 1위급인데' 의 긍부정 판정 결과는 pos입니다.
# '쏘니 오늘 오른손에 물병 들고 뛰는거 같다 멀티극장골이다!!' 의 긍부정 판정 결과는 pos입니다.
# '손흥민 하회탈 ㅋㅋㅋㅋㅋㅋ' 의 긍부정 판정 결과는 pos입니다.
# '동양이 무시하는데 저렇게 잘하다니 ㅠㅠ기죽지마!!! 아시아 전체가 널 응원한다!!넌 동양인의 자존심이다!!!' 의 긍부정 판정 결과는 pos입니다.
# '내 나이 37살에,손흥민 덕분에 부끄러운줄도 모르고 아파트 터져 나가라 소리 지르고 박수쳐봤다.아이고 속이 시원하다.고맙습니다. 나의 영웅' 의 긍부정 판정 결과는 pos입니다.
# '아스톤 빌라 키퍼 잘한다' 의 긍부정 판정 결과는 pos입니다.
# '재밌네 ㅋ 알리가 너무 놓쳐서 쉽게 갈 경기를 이렇게 어렵게 이겼네' 의 긍부정 판정 결과는 pos입니다.
# '싫어할수가 없네... 이사람 매력의 끝이 어딜까' 의 긍부정 판정 결과는 pos입니다.
# '손흥민은 컨디션 안좋아도 이제 골 넣어주는구나 전형적인 월클의 표본이다' 의 긍부정 판정 결과는 pos입니다.
# '야구는 9회말 투아웃부터라면 축구는 90분부터지~!지렸다 정말' 의 긍부정 판정 결과는 pos입니다.
# '초반 암걸리는거 참고 끝까지 본사람이 승자임 ㅋㅋ' 의 긍부정 판정 결과는 pos입니다.
# '손흥민 치달은 진심 인정이다 굿근데 전체적인 경기력은 많이 아쉽' 의 긍부정 판정 결과는 pos입니다.
# 'ㄹㅇ 지렸다 손흥민ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ세레모니까지' 의 긍부정 판정 결과는 pos입니다.
# '아.. 막판에 화장실 옘병..' 의 긍부정 판정 결과는 pos입니다.
# '월클 인정.' 의 긍부정 판정 결과는 pos입니다.
# '대한민국 축구역사상 백년만에 한번 나오기도 힘든 월드클레스 손흥민' 의 긍부정 판정 결과는 pos입니다.
# '이래서 무리뉴는 손을 빼지 않는다' 의 긍부정 판정 결과는 pos입니다.
# '손까들 나와 왜 다들 까다가 조용히 사라지고 그래?ㅌㅌ' 의 긍부정 판정 결과는 pos입니다.
# '손까들 세탁 ㅇㅈㄹ 하는거 개역겹 ㅋ 냄새나는 니들 빤스나 세탁해라' 의 긍부정 판정 결과는 pos입니다.
# '아 중하위권 원정 3무1패구나,,, 하고 있었는데 이상하게 남은 일분까지 계속 집중하고있었는데 내내 잘하던 앙헬이 엉성하게 발밑으로 볼을 떠나보낼 줄 몰랐고 흥민이가 설마하고 뛰어가던게 연결될 줄도 몰랐고 생각보다 쉽지않은 일대일을 경기내내 야신모드 레이나 상대로 뚫어버릴줄은 더더몰랐다, 거실에서 소리는 못지르고 팔 번쩍 들고 와 ㅋㅋㅋㅋㄱㅋ' 의 긍부정 판정 결과는 pos입니다.
# '모우라 흥민이 싫어하네 패스 안줌ㆍ' 의 긍부정 판정 결과는 pos입니다.
# '여기서 쏘니 까는 애들은 진심 인생패배자에 자겨지심이 가득하지 않고는 절대 이럴리가 없다. 어쨌든 두 골이란 결과를 냈고 케인 없는 상황에도 5경기 연속 골 넣었는데 대체 뭐가 잘못한거냐? 지들 인생이나 한 번 제대로 돌아보길' 의 긍부정 판정 결과는 pos입니다.
# '팀이 어려운 상황에서 손흥민 골로 꾸역승은 정말 팬들 입장에서는 환호성 지를 듯. 실수도 많았지만 어시스트급 좋은 패스들도 분명 있었고 무엇보다 2골 넣어줬으면 에이스 노릇 잘 했다! 앞으로는 좀더 실수 줄이고 완벽한 경기력 보여주면 좋겠다 힘내라ㅠ' 의 긍부정 판정 결과는 pos입니다.
# '마지막 극장골 대단하다... 팀이 원할때 해결해주는거보면 월클 자질이 있다' 의 긍부정 판정 결과는 pos입니다.
# '확실히 손흥민의 골 결정력 한방은 감독이 도저히 손흥민을 배제할 수 없는 능력 중의 하나다.' 의 긍부정 판정 결과는 pos입니다.
# '토트넘을 살렸다 대박' 의 긍부정 판정 결과는 pos입니다.
# '행복 별거있나.. 이런게 행복이지.. 기분좋다' 의 긍부정 판정 결과는 pos입니다.
# '오늘 여러모로 힘든 게임이였지만..마지막 레이나가 킥 할 때 은근 기대하게 되더라... 끝까지 포기 하지 않고 집중했기 때문에 이런 기회도 생긴거지.. 93분을 그렇게 뛰고도 마지막에 오만인상 다 쓰면서 인사이드로 미는거 슬로모션으로 보는데 감동적이였다.. 박지성과 손흥민의 시대를 살고 있고 이강인의 시대까지 함께 보다니.. 행복한거다 ㅜㅜ 5경기 연속득점 리그 51골. 멀티골.. 의미 두지 말고 계속 집중해서 해줘!!! 오늘 덕분에 즐거웠다!! ㅜㅜ' 의 긍부정 판정 결과는 pos입니다.
# '확실이 케인없는 토트넘에서는 손흥민만큼 골결정력 뛰어난 선수 없는듯 ㄷㄷ' 의 긍부정 판정 결과는 pos입니다.
# '컨디션 별로였는데 귀중한 승점 3점 챙겨주네 얜 그냥 유럽에서도 상위권 선수여' 의 긍부정 판정 결과는 pos입니다.
# 'Pk도 약간 삐끗하고 슛을 자꾸 막기좋게 중앙으로 차서 좀 그랬는데 어찌됐든 정신차리고 보니 2골이나 넣음.. 기대치가 너무 높아져서 1골 정도 넣는 정도로는 이제 만족이 안될 정도다' 의 긍부정 판정 결과는 pos입니다.
# '손흥민 MOM 안주면 이싱한, 아니 큰일날 경기였다' 의 긍부정 판정 결과는 pos입니다.
# '기사 속도보소...' 의 긍부정 판정 결과는 pos입니다.
# '그~~~~~~렇게 욕하고도 더 할게있다고 득달같이 달려드는 손까들.. 지겹지 않니??? 오늘 경기에서 설렁설렁 뛴다고 욕하더니 결국 극장 만들었는데 우짜지??' 의 긍부정 판정 결과는 pos입니다.
# 'ㅋㅋ 이게 왜 세탁이냐 ㅋㅋㅋ 평점도 최고점 받았는데 ㅋㅋ 진짜 왜 세탁이란건지 하나도 모르겠다 5경기 연속골인데 ㅋㅋㅋ 진짜 얼마나 까고싶어서 안달난거냐 ㅋㅋ' 의 긍부정 판정 결과는 pos입니다.
# '진짜 손흥민 개대박이다 진짜 소름돋는다' 의 긍부정 판정 결과는 pos입니다.
# '솔직히 손흥민 이달의 선수 각 아니냐?' 의 긍부정 판정 결과는 pos입니다.
# '손흥민은 손흥민이다!' 의 긍부정 판정 결과는 pos입니다.
# '오늘 비겼으면 무리뉴 맨유 짤릴때 시즌 2였다...수비 개구멍모드로 이길경기 비기고...비길경기 지고...질질 끌려다니다가...롱패스 남발 ...졸림하품 경기...손흥민이 살렸네...' 의 긍부정 판정 결과는 pos입니다.
# '이걸 보고 자네 내가' 의 긍부정 판정 결과는 pos입니다.
# '지금 BBC 스포츠 최상단 다 손흥민 기사임ㅎㅎㅎ' 의 긍부정 판정 결과는 pos입니다.
# '손흥민 안 빼는 것도 무리뉴의 능력이다. 그래서 이기잖아. 뭐 할 말 있냐.' 의 긍부정 판정 결과는 pos입니다.
# '흥민이 땜에 기자들 기사 다 써놨다가 다 수정했을듯 ㅋㅋㅋㅋ' 의 긍부정 판정 결과는 pos입니다.
# '역시 공격수는 90분 내내 못해도 결정적인 순간을 놓치지 않으면 됨' 의 긍부정 판정 결과는 pos입니다.
# '무리뉴가 좋아할수밖에' 의 긍부정 판정 결과는 pos입니다.
# 'Pk실축이라 찝찝했지만 어쨋든 우겨넣었고 마지막에 역전골넣었으니 된거다 손흥민은 역시 에이스다 토트넘먹여살리는건 흥민이밖에 없더라' 의 긍부정 판정 결과는 pos입니다.
# '무리뉴가 끝까지 Son 안빼는 이유다..' 의 긍부정 판정 결과는 pos입니다.
# '팀이 부진하고 폼이 떨어져도 어쨌든 경기를 뒤집어주는게 진짜 잘하는거지' 의 긍부정 판정 결과는 pos입니다.
# '이러니 못된 말을 할수가 있나 진짜 손까들은 지 스트레스 풀려 막말 못하는 손흥민 데리고 저 ㅈ5ㄹ 떠는듯 수고 많았고 일정 빡빡하니 푹 쉬어~' 의 긍부정 판정 결과는 pos입니다.
# '역습 상황에서 손흥민보다 위협적인 선수는 없다-무빡-' 의 긍부정 판정 결과는 pos입니다.
# '손까 = 일베충,느그아들래미 들 사망 극장골 ㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅ우리흥 쏘리질러 ㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅㅅ' 의 긍부정 판정 결과는 pos입니다.
# '손까들 어디 가셨나요?? 같이 좋아하신 건 아니죠??ㅎㅎㅎ' 의 긍부정 판정 결과는 pos입니다.
# '저거 솔찍히 존나 잘 차넣은거임 ㅎㄷㄷ 뭐 개 주워먹듯이 표현 하는놈들 있는데 저 상황에서 못넣는 공격수 수두룩함 ㅋㅋ 손흥민은 딱 저 각도에서 성공률 80%정도 되는듯' 의 긍부정 판정 결과는 pos입니다.
# '잠은 다 잤다 ㅋㅋㅋㅋㅋㅋㅋ 너무 좋다ㅋㅋㅋㅋㅋㅋㅋ' 의 긍부정 판정 결과는 pos입니다.
# '오늘 아스톤빌라 엄청난 손흥민 강슛 세개나 막고 마지막에 단독드리블슈팅은 막지못했음' 의 긍부정 판정 결과는 pos입니다.
# '마지막골 미쳤다..' 의 긍부정 판정 결과는 pos입니다.
# '베르통언 힘내라...' 의 긍부정 판정 결과는 pos입니다.
# '집중력도 좋고 한방이 있는 훌륭한 선수, 손흥민. 하지만 PK는 . . . . 여전히 불안하다. . 단점이면 정말 큰 단점이다. 팬이여도 못한건 못했다고 말해야지. 동작 좀 바꿨으면 좋겠다....' 의 긍부정 판정 결과는 pos입니다.
# '오늘 볼터치 등해서 전부 최악이었는데 진짜 폼안좋은 상태에서 이 악물고 뛰네. 그래도 2골 넣는거 보면 진짜 뭔가 있어.' 의 긍부정 판정 결과는 pos입니다.
# '무리뉴 이상하게 자꾸 이기네 ㅋ' 의 긍부정 판정 결과는 pos입니다.
# '오리에 진짜 쓰면 안된다 무슨크로스가 다막혀' 의 긍부정 판정 결과는 pos입니다.
# '토트넘의 에이스 우리흥! 멋지다 진짜' 의 긍부정 판정 결과는 pos입니다.
# '폼 점점 올라오네..cL때 터질듯..' 의 긍부정 판정 결과는 pos입니다.
# '프리미어리그에서 페널 얻었을때 공 잡는 선수가 대한민국사람이라는거에 순간 찌릿했다. 거기에 막판 극장골까지! 손흥민 대한민국의 자랑! 아시아의 자존심이다!👍' 의 긍부정 판정 결과는 pos입니다.
# '어려운 각도에서 손 의 능력을 봤다' 의 긍부정 판정 결과는 pos입니다.
# '손흥민은 월드클래스다 마지막골로 충분히 입증했다 그나저나 이번시즌끝나고 빨리 이적하자' 의 긍부정 판정 결과는 pos입니다.
# '무능한 무리뉴 먹여살리는 손흥민!!' 의 긍부정 판정 결과는 pos입니다.
# '스타긴 스타다 마지막 지렸다 무리뉴한테달려가야지ㅠㅠㅋ' 의 긍부정 판정 결과는 pos입니다.
# '우리 흥미니는 역습하나만 걸리면됨' 의 긍부정 판정 결과는 pos입니다.
# '아 레이나때메 환장하는지 알앗다 그리고 루카스모우라 잘했다 폼이 이제 올라오네 다이어는 아에 센터백으로 쓰는게 나을거같고 미들은 로셀소 무조건 있어야돼' 의 긍부정 판정 결과는 pos입니다.
# '2월의선수상 수상 가즈아~~~' 의 긍부정 판정 결과는 pos입니다.
# '느그흥 볼터치 십망ㅋㅋㅋㅋㅋㅋ' 의 긍부정 판정 결과는 pos입니다.
# '아무리 1대1 상황이라고 해도 94분에 전력질주해서 골키퍼 옆으로 침착하게 넣을수 있는 선수는 전세계에 몇명 없다.' 의 긍부정 판정 결과는 pos입니다.
# '하회탈 그표정땜에 세레모니 간지력이 줄어듦 ㄹㅇ홍진경 너무 닮았엉' 의 긍부정 판정 결과는 pos입니다.
# '손까들 넣어도 ㅈㄹ 못넣어도 ㅈㄹ pk세탁 이 ㅈㄹ하면서 마지막 골은 1도 말안하네' 의 긍부정 판정 결과는 pos입니다.
# '이런 골은 진짜 아무나 못 넣는 골이다. 임팩트 하나는 역시 손흥민인 듯. 월클 인정.' 의 긍부정 판정 결과는 pos입니다.
# '쏘니는 잘했고 직장인들은 월요일이다 자자 ㅋㅋ' 의 긍부정 판정 결과는 pos입니다.
# '신기힌게 경기중에는 손까 밖에 없었거든? 근데 지금 댓글은 다 손뽕임.. 손까 다 어디감?ㅋㅋㅋ' 의 긍부정 판정 결과는 pos입니다.
# '볼을 왜 자꾸 키퍼있는데로 차내' 의 긍부정 판정 결과는 pos입니다.
# '손흥민: 손까들? 조용히 하고있어ㅎㅎ자랑스럽습니다 손흥민!!' 의 긍부정 판정 결과는 pos입니다.
# '근데 그릴리시 잘하더라' 의 긍부정 판정 결과는 pos입니다.
# '이거 기사 다 써놓고 마지막 한줄만 바꿔 올린 기사다 ㅋㅋㅋ' 의 긍부정 판정 결과는 pos입니다.
# '못하는데 잘해!!!!' 의 긍부정 판정 결과는 pos입니다.
# '레이나는 진짜 개잘막더라.. 손흥민은 진짜 공격수는 골이라는걸 제대로 보여주네... 개잘한다.. 5경기 연속골ㄷㄷㄷ' 의 긍부정 판정 결과는 pos입니다.
# '수비수는 9번을 잘 막아도 1번 실수하면 역적이 되고, 공격수는 찬스 9번을 놓쳐도 1골로 영웅이 된다는 말을 실감한 경기였음. 암튼 마지막 감각적인 슛 지렸다' 의 긍부정 판정 결과는 pos입니다.
# '상대방수비실책 줏어먹기 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ안창피하나' 의 긍부정 판정 결과는 pos입니다.
# '오늘 손흥민 볼터치 봐라. 진짜 우레이를 보는듯. 운으로 두 골 주워는 먹었다만' 의 긍부정 판정 결과는 pos입니다.
# '이게 포체티노 하에서는 나올 수 없는 골. 소니는 항상 70분 경에 뺐으니까.' 의 긍부정 판정 결과는 pos입니다.
# '진짜 오리에좀 어떻게 안되겠니? 진짜 고구마 먹고 채한 기분이다.' 의 긍부정 판정 결과는 pos입니다.
# '레이나 삼각팬티 절규짤도 웃겼는데ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ' 의 긍부정 판정 결과는 pos입니다.
# '애는뭐지 이생각뿐 드라마만들줄아는놈이야ㅋㅋ' 의 긍부정 판정 결과는 pos입니다.
# '알리,베르나인,모우라보이지 않는곳에 잘 해줌소농민 폼은 작년대비 60~70프로 수준~골 넣어서 다행이고~ 축카글고 소농민 패스 빨리좀 할것내 생각~토튼햄 경기력은 리그 10~15위 수준정도' 의 긍부정 판정 결과는 pos입니다.
# '선발부터 다이가아닌 로셀소엿다면 쉽게갈수잇는경기엿을텐데,, 강등권하위팀이라 너무안일하게대처한것이 힘든경기를 자초한거같다.' 의 긍부정 판정 결과는 pos입니다.
# '너는 계획이 다 있구나' 의 긍부정 판정 결과는 pos입니다.
# '손흥민은 패널티찰때 멈칫멈칫 하지말고 차는 연습해라.' 의 긍부정 판정 결과는 pos입니다.
# '솔직히 동점골 먹히고 찬스 계속 놓치길래 걍 안볼려 했는데 뭔가 느낌이 역전골 넣을거 같다 생각해서 끝까지 봤는데 이걸 손흥민이 극장골을 넣어버리네 역시 우리흥!' 의 긍부정 판정 결과는 pos입니다.
# '모우라 알리는 답이 없다에이스는 우리 흥!' 의 긍부정 판정 결과는 pos입니다.
# '무리뉴는 머리 기르는게 낫다' 의 긍부정 판정 결과는 pos입니다.
# '무리뉴 급하게 슈퍼얀 부름 ㅋㅋㅋㅋ' 의 긍부정 판정 결과는 pos입니다.
# '진짜 손흥민은 토트넘 에이스다' 의 긍부정 판정 결과는 pos입니다.
# '월드클래스 우리흥!' 의 긍부정 판정 결과는 pos입니다.
# '손흥민 다음 피파에선 슈팅 79 결정력 80 으로 낮춰야함. 골들이 죄다 운빨임' 의 긍부정 판정 결과는 pos입니다.
# '페널티 봉산탈춤 졸웃김 ㅋㅋㅋ 공격수 맞음? 오늘도 여전히 못했지만 상대 수비수 실책으로 세탁성공' 의 긍부정 판정 결과는 pos입니다.
# '손홍민이 체력과 폼이 좀 떨어지기는 했는데 그래도 해줄때는 해주네 PK는 심리전이다 너무 생각이 많거나 불필요한 동작이 많으면 안 좋다 심플하게 차라' 의 긍부정 판정 결과는 pos입니다.
# '원톱은 케인이아니라 손흥민자리다' 의 긍부정 판정 결과는 pos입니다.
# '트레이블레이져 트레이블레이져~~ 지겨워 죽겠네' 의 긍부정 판정 결과는 pos입니다.
# '손룽민이 망칠뻔한 경기, 어부지리로 골 넣다고 평가가 달라지는건 아님. 보는내내 개답답 발암. 토트넘의 가장 큰 구멍은 손룽민. 케인이 그립다. 손룽민은 후반 조커가 딱임' 의 긍부정 판정 결과는 pos입니다.
# '4위 첼시와 승점 1점차 다음 리그 상대인 첼시와 박터지게 붙어야 겠네 빅게임 될듯..' 의 긍부정 판정 결과는 pos입니다.
# '참나..경기내내 흥미니..욕햇건만 마지막에흥미니 영웅됫네~ㅋㅋ경기는 끝날때까지 끝난게 아니네~인생같다.' 의 긍부정 판정 결과는 pos입니다.
# '끝날때까지 봐야하는이유....휘슬 불때까지 끝난게아니다 극적인드라마' 의 긍부정 판정 결과는 pos입니다.
# '경기 내내 조마조마하다 막판 개짜릿~~' 의 긍부정 판정 결과는 pos입니다.
# '레이나 다 처막아서 짜증나서 비기나보다 하고 있었는데 마지막에 지림' 의 긍부정 판정 결과는 pos입니다.
# '이맛에 이시간까지본다~잘했다 흥민아~~^^' 의 긍부정 판정 결과는 pos입니다.
# '경기력과 결과의 갭을 줄이는사람은 손흥민밖에없다 경기력이 별로라 욕하려고해도 이런장면 때문에 욕을할수가없음' 의 긍부정 판정 결과는 pos입니다.
# '누가 나불렀냐' 의 긍부정 판정 결과는 pos입니다.
# '인직 만숙 극장골' 의 긍부정 판정 결과는 pos입니다.
# '오늘 결정적 찬스 놓친거 알리 4개, 손흥민 3개, 모우라 2개, 베르바인 2개, 총 11개. 그런데 이중 8개는 레이나가 직접 막아냈다는 것, 대단하다.' 의 긍부정 판정 결과는 pos입니다.
# '그나저나 흥민이 폼이 많이 떨어진것 같아안탑까워 오늘경기 해드트릭감인데' 의 긍부정 판정 결과는 pos입니다.
# '이제 터치랑 드리블 폼좀 올라오자ㅠ 너무 심하지않냐 ㅠ' 의 긍부정 판정 결과는 pos입니다.
# '안자길 잘했다 ㅋㅋㅋ 꿀잼내일 출근 힘내야지' 의 긍부정 판정 결과는 pos입니다.
# '경기력 좋았던건 아닌데 케인부상때만되면먹여살리네...' 의 긍부정 판정 결과는 pos입니다.
# '진짜 네이버 댓글 손까들 역겹던데 이걸 이기게 해주네 죽어라 까도 골 넣는건 손흥민이다!!!!' 의 긍부정 판정 결과는 pos입니다.
# '우리는 손흥민의 시대에 살고있다' 의 긍부정 판정 결과는 pos입니다.
# '손흥민 대통령 하자' 의 긍부정 판정 결과는 pos입니다.
# '하 소름끼쳤다 ㄹㅇ;;;;;' 의 긍부정 판정 결과는 pos입니다.
# '축구 한두번 보나?? 공격수는 골로 말하고 이기면 장땡임 ㅋㅋㅋ' 의 긍부정 판정 결과는 pos입니다.
# '아재들이 특별히 손흥민을 더 좋아하는 이유가 이전까지 대한민국의 스트라이커라는 새끼들이 죄다 문전에서 질알 쌩쑈를 해놔서 기대감 자체가 없었는데 손흥민은 다르다는 것이지' 의 긍부정 판정 결과는 pos입니다.
# '언제적 레이나냐? 골키퍼의 수명이 정말 길긴 길다..부폰.레이나...' 의 긍부정 판정 결과는 pos입니다.
# '니네 그거 아냐?? 지성이형 맨유 있을 때 피엘볼맛났고 지송이형 은퇴 해가고 기성용이 청룡이 그나마 활약하면서 근근히 골소식 보면서 행복했고 그자리 흥미니 독일서 넘어와 지금 전성기 보여주면서 꿀잼인데 훙민이 한 3년 지나면 슬슬 폼 떨어지는 순간 우린좟되는거다. 이제 피엘 및 유럽축구 10노잼 될듯하다. 저어기 변방리그 이승우 뛰냐 안뛰냐가 꿀잼될듯' 의 긍부정 판정 결과는 pos입니다.
# '내가 진짜 흥민이 때문에 즐겁게 산다. 고맙다 흥민아!!!!' 의 긍부정 판정 결과는 pos입니다.
# '마지막 결승골 넣을때 진짜 미친듯이 소리 질렀다' 의 긍부정 판정 결과는 pos입니다.
# '하회탈 세리모니 지렸다...ㅎㅎ' 의 긍부정 판정 결과는 pos입니다.
# '솔찍히 손까들한테 하고 싶은 말이 있는데, 니들은 대한민국을 위해서 한 일이 뭐냐? 쳐 먹고 싸지르는거??' 의 긍부정 판정 결과는 pos입니다.
# 'ㅋㅋㅋㅋㅋ 솔직히 월클은 아니더라도 리그탑급인건 인정 박자' 의 긍부정 판정 결과는 pos입니다.
# '손흥민은정말 완벽한공격수다 외모 키 비율 덩치 모든게다멋지다 마네 스털링 캉테 이니에스타 이런 쪼만한 몬생긴애들이랑은차원이달음 갓흥민' 의 긍부정 판정 결과는 pos입니다.
# '뭐가 그동안 한국에 없던 유형임? 솔직히 최용수 선수시절 때가 손흥민과 비슷한 유형이면서 실력 훨씬 좋았음' 의 긍부정 판정 결과는 pos입니다.
# '솔직히 나였어도 넣었다. 운은 하여간 오지게 좋음. 실력은 우레이급인데 우레이가 빡칠만 함. 게나가 나였으면 패널도 성공임' 의 긍부정 판정 결과는 pos입니다.
# '이건 승부조작 의심해봐야한다' 의 긍부정 판정 결과는 pos입니다.
# '오늘도 못했는데 상대수비수 실책으로 세탁' 의 긍부정 판정 결과는 pos입니다.
# '클라스 있는 선수는 폼이 안좋아도 중요한 순간에 골을 넣는다' 의 긍부정 판정 결과는 pos입니다.
# '졸라 못하다가 막판에 한 건 ㅋㅋㅋ' 의 긍부정 판정 결과는 pos입니다.
# '오늘 진짜 대박!!!!!' 의 긍부정 판정 결과는 pos입니다.
# '손흥민은 한국에서 그 누구보다 잘나감.증거손흥민한테 쓸때없이 시기질투해서 까는애들 많음= 사실상 흥행보증' 의 긍부정 판정 결과는 pos입니다.
# '네 다음 경기 무관민 담당일진 뤼디거 나오세요ㅋㅋㅋ ^무^' 의 긍부정 판정 결과는 pos입니다.
# '살라하고 요즘 손이 비슷하다. 폼이 죽어서 실수 많이 하는데 결정적일 때 반드시 골을 넣는다.' 의 긍부정 판정 결과는 pos입니다.
# '희한하게 애스톤빌라쪽으로 공들이 달라붙더만. 토트넘 슛들은 죄다 수비수들한테 막히고.' 의 긍부정 판정 결과는 pos입니다.
# '오늘 군입대 선물 잘 받았다' 의 긍부정 판정 결과는 pos입니다.
# '근데 만약 저 상황에서 이동국이였다면 넣었을까요?... 충분히 넣었을것이다면 공감 ... 절대 못 넣었을거다라면 비공감을 눌러주세요' 의 긍부정 판정 결과는 pos입니다.
# '대한민국 만세' 의 긍부정 판정 결과는 pos입니다.
# '손흥민 개쩔어...^^' 의 긍부정 판정 결과는 pos입니다.
# '손까들 특: 골넣은 날 베뎃에 많이,기생한다 버글 버글하다 손까 벌레들' 의 긍부정 판정 결과는 pos입니다.
# '진짜 솔직히 손까도아니고 손뽕도아니고 중립적으로 봤을때 골을 매번넣는건 솔직히 진짜 공격수로서 1인분은 해주는의미니까 대단한건데 골빼고 그냥 전체적인 폼봤을때는 잘한다는 느낌은 안듦... 그래서 잘하는건지 못하는건지 되게 애매해..' 의 긍부정 판정 결과는 pos입니다.
# '초반에 부딛치지 않았으면 4골도 가능 했는데' 의 긍부정 판정 결과는 pos입니다.
# '베르바인>>>>알라' 의 긍부정 판정 결과는 pos입니다.
# '아스톤빌라 드링크워터선수는 우리나라말로 물마셔 선수인가요?ㅋㅋㅋ' 의 긍부정 판정 결과는 pos입니다.
# '모우라 말고 진짜 누구 없냐...' 의 긍부정 판정 결과는 pos입니다.
# '토트넘홈페이지는 손 졸라욕하는데골이 그나마 살렸네' 의 긍부정 판정 결과는 pos입니다.
# '모처럼 우레이 골넣었는데 흥민이 멀티골로 박아버리네ㅋㅋㅋ' 의 긍부정 판정 결과는 pos입니다.
# '경기 내내 앉아만 있었어도 역전골, 재역전골로 승점 3점 땄으면 공격수 할 일 다 한 거다.' 의 긍부정 판정 결과는 pos입니다.
# '토트넘 쏘니 다침 대체자 있나? 정말 오늘보니 실력있는 선수 너무 부족ㅜ 맨시티에서 좀 데고 오길' 의 긍부정 판정 결과는 pos입니다.
# '오늘손흥민 4골정도 는 성공했어야 함' 의 긍부정 판정 결과는 pos입니다.
# '폼이 좋진않은데 그래도 멀티골쑤셔박는거보니 손흥민은 손흥민이다ㅎㅎ' 의 긍부정 판정 결과는 pos입니다.
# '이밤에 나혼자 소리지르고 어퍼컷 날리고 난리났었다.' 의 긍부정 판정 결과는 pos입니다.
# '폼이 올라오지 않았는데도 결국은 결승골을 넣는다. ㅋ 실력도 최고 운도 최고. 에이스의 운명이지. ㅎ' 의 긍부정 판정 결과는 pos입니다.
# '후반까지 보길 잘함 캬 내일 출근은... ㅠ' 의 긍부정 판정 결과는 pos입니다.
# '우리 흥 월클이다 손까들아 그만좀까라!!!' 의 긍부정 판정 결과는 pos입니다.
# '쉽게 갈수도 있었는데 레이나가 잘했고, 손흥민은 톱 자리가 편해 보이지 않더라. 토트넘이 분위기를 주도하지 못했기도 했고, 아스턴빌라가 잘했다. 그러나 역시 축구나 인생이나 한방이고, 될놈은 된다. ㅎㅎ' 의 긍부정 판정 결과는 pos입니다.
# '손흥민 극장골 넣어서 좋긴한데 엥헬스는 마음아프네 ㅋㅋㅋㅋ' 의 긍부정 판정 결과는 pos입니다.
# '모우라 진짜 답없네' 의 긍부정 판정 결과는 pos입니다.
# '손흥민 팔 안좋아보이던데 괜찮기를~!!' 의 긍부정 판정 결과는 pos입니다.
# '폼 안좋아도 이렇게 꾸역꾸역 해주는게 에이스지' 의 긍부정 판정 결과는 pos입니다.
# '수비실수를 그대로 넣어버리네. 90분 재밌게 봤다' 의 긍부정 판정 결과는 pos입니다.
# '현지해설이 너무 궁금하다' 의 긍부정 판정 결과는 pos입니다.
# '손까는 바퀴벌레' 의 긍부정 판정 결과는 pos입니다.
# '와~~월드컵 독일전때 막판 손흥민 다시등장눈물날뻔ㅜ' 의 긍부정 판정 결과는 pos입니다.

# %%
print("pos 표현의 갯수는 " + str(pos_count) + "개 이며, 약 " + str(round(pos_count/total_length*100,2)) + "%입니다.")
print("neg 표현의 갯수는 " + str(neg_count) + "개 이며, 약 " + str(round(neg_count/total_length*100,2)) + "%입니다.")
# Out:
# pos 표현의 갯수는 237개 이며, 약 99.16%입니다.
# neg 표현의 갯수는 2개 이며, 약 0.84%입니다.
